# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# dataset load
data = pd.read_csv(r"C:\Users\revan\Downloads\restaurant_customer_satisfaction.csv")

# %%
data
# Out:
#       CustomerID  Age  Gender  Income VisitFrequency  AverageSpend  \
# 0            654   35    Male   83380         Weekly     27.829142
# 1            655   19    Male   43623         Rarely    115.408622
# 2            656   41  Female   83737         Weekly    106.693771
# 3            657   43    Male   96768         Rarely     43.508508
# 4            658   55  Female   67937        Monthly    148.084627
# ...          ...  ...     ...     ...            ...           ...
# 1495        2149   39    Male  114857        Monthly    163.015254
# 1496        2150   37  Female  133506         Weekly    190.991911
# 1497        2151   46    Male  119159        Monthly    150.088604
# 1498        2152   24    Male   27970         Weekly    196.363626
# 1499        2153   51    Male  148333         Weekly    171.119498
#
#      PreferredCuisine TimeOfVisit  GroupSize DiningOccasion  MealType  \
# 0             Chinese   Breakfast          3       Business  Takeaway
# ...

# %%
data.head(26)
# Out:
#     CustomerID  Age  Gender  Income VisitFrequency  AverageSpend  \
# 0          654   35    Male   83380         Weekly     27.829142
# 1          655   19    Male   43623         Rarely    115.408622
# 2          656   41  Female   83737         Weekly    106.693771
# 3          657   43    Male   96768         Rarely     43.508508
# 4          658   55  Female   67937        Monthly    148.084627
# 5          659   42  Female   28860        Monthly    111.064696
# 6          660   20  Female  131104         Weekly    120.236707
# 7          661   51  Female  137882         Weekly    160.979098
# 8          662   27    Male  149638         Weekly     56.558632
# 9          663   32  Female  136145         Weekly     65.753455
# 10         664   21    Male   79249        Monthly     39.235383
# 11         665   59    Male   94208         Weekly    132.994918
# 12         666   32  Female  143471        Monthly    156.130808
# ...

# %%
data.tail(10)
# Out:
#       CustomerID  Age  Gender  Income VisitFrequency  AverageSpend  \
# 1490        2144   20    Male  106717         Rarely    105.323720
# 1491        2145   47    Male   90569         Weekly    101.312053
# 1492        2146   20    Male   41041         Rarely     59.403047
# 1493        2147   62    Male  135684         Weekly    128.943101
# 1494        2148   25  Female  142332         Weekly    128.626784
# 1495        2149   39    Male  114857        Monthly    163.015254
# 1496        2150   37  Female  133506         Weekly    190.991911
# 1497        2151   46    Male  119159        Monthly    150.088604
# 1498        2152   24    Male   27970         Weekly    196.363626
# 1499        2153   51    Male  148333         Weekly    171.119498
#
#      PreferredCuisine TimeOfVisit  GroupSize DiningOccasion  MealType  \
# 1490           Indian   Breakfast          5         Casual  Takeaway
# 1491           Indian       Lunch          9         Casual  Takeaway
# ...

# %%
# Average Spend by Gender
avg_spend_by_gender = data.groupby('Gender')['AverageSpend'].mean()
print(avg_spend_by_gender)
# Out:
# Gender
# Female    105.471643
# Male      105.850916
# Name: AverageSpend, dtype: float64

# %%
# Visualizing Average Spend by Gender
plt.figure(figsize=(8,6))
sns.barplot(x=['Female', 'Male'], y=avg_spend_by_gender.values)
plt.title('Average Spend by Gender')
plt.xlabel('Gender')
plt.ylabel('Average Spend')
plt.show()

# %%
# Distribution of customer ages
plt.figure(figsize=(10,6))
sns.histplot(data['Age'], bins=10, kde=True)
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %%
# Correlation between Wait Time and Service Rating, Food Rating, Ambiance Rating
correlation = data[['WaitTime', 'ServiceRating', 'FoodRating', 'AmbianceRating']].corr()
print(correlation)
# Out:
#                 WaitTime  ServiceRating  FoodRating  AmbianceRating
# WaitTime        1.000000       0.017338    0.036792       -0.014251
# ServiceRating   0.017338       1.000000    0.005013        0.003501
# FoodRating      0.036792       0.005013    1.000000        0.025910
# AmbianceRating -0.014251       0.003501    0.025910        1.000000

# %%
# Heatmap of correlations
plt.figure(figsize=(8,6))
sns.heatmap(correlation, annot=True, cmap="coolwarm")
plt.title('Correlation Matrix')
plt.show()

# %%
# Satisfaction Analysis: Correlation of HighSatisfaction with other factors
satisfaction_corr = data[['HighSatisfaction', 'WaitTime', 'ServiceRating', 'FoodRating', 'AmbianceRating']].corr()
print(satisfaction_corr)
# Out:
#                   HighSatisfaction  WaitTime  ServiceRating  FoodRating  \
# HighSatisfaction          1.000000 -0.143939       0.089612    0.138709
# WaitTime                 -0.143939  1.000000       0.017338    0.036792
# ServiceRating             0.089612  0.017338       1.000000    0.005013
# FoodRating                0.138709  0.036792       0.005013    1.000000
# AmbianceRating            0.077656 -0.014251       0.003501    0.025910
#
#                   AmbianceRating
# HighSatisfaction        0.077656
# WaitTime               -0.014251
# ServiceRating           0.003501
# FoodRating              0.025910
# AmbianceRating          1.000000

# %%
# Bar plot of satisfaction levels by gender
plt.figure(figsize=(10,6))
sns.barplot(x='Gender', y='HighSatisfaction', data=data)
plt.title('High Satisfaction by Gender')
plt.xlabel('Gender')
plt.ylabel('High Satisfaction')
plt.show()

# %%
# Scatter plot of Wait Time vs Satisfaction
plt.figure(figsize=(10,6))
sns.scatterplot(data=data, x='WaitTime', y='HighSatisfaction', hue='Gender')
plt.title('Wait Time vs High Satisfaction')
plt.xlabel('Wait Time')
plt.ylabel('High Satisfaction')
plt.show()

# %%
# Box plot of Service Rating by Dining Occasion
plt.figure(figsize=(10,6))
sns.boxplot(data=data, x='DiningOccasion', y='ServiceRating')
plt.title('Service Rating by Dining Occasion')
plt.show()

# %%
# Convert DataFrame to numpy array for analysis
data_np = data.to_numpy()

# %%
# Basic Statistics
print("Basic Statistics:")
print(f"Mean Age: {np.mean(data_np[:, 1])}")
print(f"Mean Income: {np.mean(data_np[:, 3])}")
print(f"Mean Average Spend: {np.mean(data_np[:, 5])}")
print(f"Mean Wait Time: {np.mean(data_np[:, 14])}")
# Out:
# Basic Statistics:
# Mean Age: 43.832
# Mean Income: 85921.89
# Mean Average Spend: 105.65900359407256
# Mean Wait Time: 30.163550080905882

# %%
# Median values
print("\nMedian Values:")
print(f"Median Age: {np.median(data_np[:, 1])}")
print(f"Median Income: {np.median(data_np[:, 3])}")
print(f"Median Average Spend: {np.median(data_np[:, 5])}")
print(f"Median Wait Time: {np.median(data_np[:, 14])}")
# Out:
# Median Values:
# Median Age: 44.0
# Median Income: 85811.0
# Median Average Spend: 104.62640814349791
# Median Wait Time: 30.044054798202183

# %%
# Standard Deviation
print("\nStandard Deviations:")
print(f"Standard Deviation of Age: {np.std(data_np[:, 1])}")
print(f"Standard Deviation of Income: {np.std(data_np[:, 3])}")
print(f"Standard Deviation of Average Spend: {np.std(data_np[:, 5])}")
print(f"Standard Deviation of Wait Time: {np.std(data_np[:, 14])}")
# Out:
# Standard Deviations:
# Standard Deviation of Age: 14.962167044471402
# Standard Deviation of Income: 38170.32194312617
# Standard Deviation of Average Spend: 52.36438510138078
# Standard Deviation of Wait Time: 17.208444574082193

# %%
# High Satisfaction Rate
high_satisfaction_rate = np.mean(data_np[:, 17])
print(f"\nHigh Satisfaction Rate: {high_satisfaction_rate:.2%}")
# Out:
# High Satisfaction Rate: 298.73%

# %%
plt.figure(figsize=(12, 6))
sns.histplot(data['Age'], bins=10, kde=True, color='skyblue')
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.histplot(data['Income'], bins=30, kde=True, color='lightgreen')
plt.title('Income Distribution')
plt.xlabel('Income')
plt.ylabel('Frequency')
plt.show()

# %%
sns.catplot(x='GroupSize', y='WaitTime', data=df, kind='point', hue='HighSatisfaction', palette='coolwarm')
plt.title('Wait Time vs. Group Size')
plt.xlabel('Group Size')
plt.ylabel('Wait Time')
plt.show()
