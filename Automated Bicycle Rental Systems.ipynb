# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# dataset load
data = pd.read_csv(r"C:\Users\revan\Downloads\day.csv")

# %%
data
# Out:
#      instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0          1  2011-01-01       1   0     1        0        6           0
# 1          2  2011-01-02       1   0     1        0        0           0
# 2          3  2011-01-03       1   0     1        0        1           1
# 3          4  2011-01-04       1   0     1        0        2           1
# 4          5  2011-01-05       1   0     1        0        3           1
# ..       ...         ...     ...  ..   ...      ...      ...         ...
# 726      727  2012-12-27       1   1    12        0        4           1
# 727      728  2012-12-28       1   1    12        0        5           1
# 728      729  2012-12-29       1   1    12        0        6           0
# 729      730  2012-12-30       1   1    12        0        0           0
# 730      731  2012-12-31       1   1    12        0        1           1
#
#      weathersit      temp     atemp       hum  windspeed  casual  registered  \
# ...

# %%
data.head(45)
# Out:
#     instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0         1  2011-01-01       1   0     1        0        6           0
# 1         2  2011-01-02       1   0     1        0        0           0
# 2         3  2011-01-03       1   0     1        0        1           1
# 3         4  2011-01-04       1   0     1        0        2           1
# 4         5  2011-01-05       1   0     1        0        3           1
# 5         6  2011-01-06       1   0     1        0        4           1
# 6         7  2011-01-07       1   0     1        0        5           1
# 7         8  2011-01-08       1   0     1        0        6           0
# 8         9  2011-01-09       1   0     1        0        0           0
# 9        10  2011-01-10       1   0     1        0        1           1
# 10       11  2011-01-11       1   0     1        0        2           1
# 11       12  2011-01-12       1   0     1        0        3           1
# ...

# %%
data.tail(34)
# Out:
#      instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 697      698  2012-11-28       4   1    11        0        3           1
# 698      699  2012-11-29       4   1    11        0        4           1
# 699      700  2012-11-30       4   1    11        0        5           1
# 700      701  2012-12-01       4   1    12        0        6           0
# 701      702  2012-12-02       4   1    12        0        0           0
# 702      703  2012-12-03       4   1    12        0        1           1
# 703      704  2012-12-04       4   1    12        0        2           1
# 704      705  2012-12-05       4   1    12        0        3           1
# 705      706  2012-12-06       4   1    12        0        4           1
# 706      707  2012-12-07       4   1    12        0        5           1
# 707      708  2012-12-08       4   1    12        0        6           0
# 708      709  2012-12-09       4   1    12        0        0           0
# ...

# %%
data.isnull()
# Out:
#      instant  dteday  season     yr   mnth  holiday  weekday  workingday  \
# 0      False   False   False  False  False    False    False       False
# 1      False   False   False  False  False    False    False       False
# 2      False   False   False  False  False    False    False       False
# 3      False   False   False  False  False    False    False       False
# 4      False   False   False  False  False    False    False       False
# ..       ...     ...     ...    ...    ...      ...      ...         ...
# 726    False   False   False  False  False    False    False       False
# 727    False   False   False  False  False    False    False       False
# 728    False   False   False  False  False    False    False       False
# 729    False   False   False  False  False    False    False       False
# 730    False   False   False  False  False    False    False       False
#
#      weathersit   temp  atemp    hum  windspeed  casual  registered    cnt
# ...

# %%
data.isna().sum()
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %%
# Summary statistics
print(data.describe())
# Out:
#           instant      season          yr        mnth     holiday     weekday  \
# count  731.000000  731.000000  731.000000  731.000000  731.000000  731.000000
# mean   366.000000    2.496580    0.500684    6.519836    0.028728    2.997264
# std    211.165812    1.110807    0.500342    3.451913    0.167155    2.004787
# min      1.000000    1.000000    0.000000    1.000000    0.000000    0.000000
# 25%    183.500000    2.000000    0.000000    4.000000    0.000000    1.000000
# 50%    366.000000    3.000000    1.000000    7.000000    0.000000    3.000000
# 75%    548.500000    3.000000    1.000000   10.000000    0.000000    5.000000
# max    731.000000    4.000000    1.000000   12.000000    1.000000    6.000000
#
#        workingday  weathersit        temp       atemp         hum   windspeed  \
# count  731.000000  731.000000  731.000000  731.000000  731.000000  731.000000
# mean     0.683995    1.395349    0.495385    0.474354    0.627894    0.190486
# ...

# %%
# Scatter plot of temperature vs rental count
plt.figure(figsize=(8, 6))
sns.scatterplot(x='temp', y='cnt', data=data)
plt.title('Temperature vs Rental Count')
plt.xlabel('Temperature')
plt.ylabel('Rental Count')
plt.show()

# %%
# Line plot of count over time
plt.figure(figsize=(10, 6))
sns.lineplot(x='dteday', y='cnt', data=data)
plt.title('Rental Count Over Time')
plt.xlabel('Date')
plt.ylabel('Rental Count')
plt.show()

# %%
# Group by weekday
weekday_group = data.groupby('weekday')['cnt'].mean()

# %%
# Bar plot of average rentals by weekday
plt.figure(figsize=(8, 6))
sns.barplot(x=weekday_group.index, y=weekday_group.values)
plt.title('Average Rentals by Weekday')
plt.xlabel('Weekday (0 = Sunday)')
plt.ylabel('Average Rental Count')
plt.show()

# %%
# Distribution of 'temp' (Temperature)
sns.histplot(data['temp'], kde=True)
plt.title("Distribution of Temperature")
plt.show()

# %%
# Scatter plot for temperature vs total count
sns.scatterplot(x='temp', y='cnt', data=data)
plt.title("Temperature vs Total Count")
plt.show()

# %%
# Pairplot to explore relationships between multiple variables
sns.pairplot(data[['temp', 'hum', 'windspeed', 'cnt']])
plt.show()

# %%
data1 = pd.read_csv(r"C:\Users\revan\Downloads\hour.csv")

# %%
data1
# Out:
#        instant      dteday  season  yr  mnth  hr  holiday  weekday  \
# 0            1  2011-01-01       1   0     1   0        0        6
# 1            2  2011-01-01       1   0     1   1        0        6
# 2            3  2011-01-01       1   0     1   2        0        6
# 3            4  2011-01-01       1   0     1   3        0        6
# 4            5  2011-01-01       1   0     1   4        0        6
# ...        ...         ...     ...  ..   ...  ..      ...      ...
# 17374    17375  2012-12-31       1   1    12  19        0        1
# 17375    17376  2012-12-31       1   1    12  20        0        1
# 17376    17377  2012-12-31       1   1    12  21        0        1
# 17377    17378  2012-12-31       1   1    12  22        0        1
# 17378    17379  2012-12-31       1   1    12  23        0        1
#
#        workingday  weathersit  temp   atemp   hum  windspeed  casual  \
# 0               0           1  0.24  0.2879  0.81     0.0000       3
# ...

# %%
data1.head(30)
# Out:
#     instant      dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0         1  2011-01-01       1   0     1   0        0        6           0
# 1         2  2011-01-01       1   0     1   1        0        6           0
# 2         3  2011-01-01       1   0     1   2        0        6           0
# 3         4  2011-01-01       1   0     1   3        0        6           0
# 4         5  2011-01-01       1   0     1   4        0        6           0
# 5         6  2011-01-01       1   0     1   5        0        6           0
# 6         7  2011-01-01       1   0     1   6        0        6           0
# 7         8  2011-01-01       1   0     1   7        0        6           0
# 8         9  2011-01-01       1   0     1   8        0        6           0
# 9        10  2011-01-01       1   0     1   9        0        6           0
# 10       11  2011-01-01       1   0     1  10        0        6           0
# ...

# %%
data1.tail(24)
# Out:
#        instant      dteday  season  yr  mnth  hr  holiday  weekday  \
# 17355    17356  2012-12-31       1   1    12   0        0        1
# 17356    17357  2012-12-31       1   1    12   1        0        1
# 17357    17358  2012-12-31       1   1    12   2        0        1
# 17358    17359  2012-12-31       1   1    12   3        0        1
# 17359    17360  2012-12-31       1   1    12   4        0        1
# 17360    17361  2012-12-31       1   1    12   5        0        1
# 17361    17362  2012-12-31       1   1    12   6        0        1
# 17362    17363  2012-12-31       1   1    12   7        0        1
# 17363    17364  2012-12-31       1   1    12   8        0        1
# 17364    17365  2012-12-31       1   1    12   9        0        1
# 17365    17366  2012-12-31       1   1    12  10        0        1
# 17366    17367  2012-12-31       1   1    12  11        0        1
# 17367    17368  2012-12-31       1   1    12  12        0        1
# ...

# %%
print(data1.isnull().sum())
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# hr            0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %%
# Mean
mean_temp = np.mean(temp)
mean_cnt = np.mean(cnt)

# Median
median_temp = np.median(temp)
median_cnt = np.median(cnt)

# Standard Deviation
std_temp = np.std(temp)
std_cnt = np.std(cnt)

print(f'Mean Temp: {mean_temp}, Mean Count: {mean_cnt}')
print(f'Median Temp: {median_temp}, Median Count: {median_cnt}')
print(f'Standard Deviation Temp: {std_temp}, Count: {std_cnt}')
# Out:
# Mean Temp: 0.4969871684216583, Mean Count: 189.46308763450142
# Median Temp: 0.5, Median Count: 142.0
# Standard Deviation Temp: 0.19255058126205624, Count: 181.38238043116908

# %%
total_rentals = np.sum(cnt)
total_rentals_jan = np.sum(cnt[data1['mnth'] == 1])
print(f'Total Rentals: {total_rentals}')
print(f'Total Rentals in January: {total_rentals_jan}')
# Out:
# Total Rentals: 3292679
# Total Rentals in January: 134933

# %%
# Catplot to show the relationship between hour of the day and total count (cnt)
sns.catplot(x='hr', y='cnt', data=data1, kind='bar', aspect=2)
plt.title("Hourly Bike Rentals")
plt.show()
