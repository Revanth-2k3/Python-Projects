# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# dataset load
data = pd.read_csv(r"C:\Users\revan\Downloads\IMDb_Dataset.csv")

# %%
data
# Out:
#                                              Title  IMDb Rating  Year  \
# 0                                        Gladiator          8.5  2000
# 1    Mission: Impossible - Dead Reckoning Part One          7.7  2023
# 2             Rebel Moon - Part Two: The Scargiver          5.2  2024
# 3                             Inglourious Basterds          8.4  2009
# 4                                      Borderlands          7.1  2024
# ..                                             ...          ...   ...
# 395                            Mother of the Bride          4.8  2024
# 396                        Beetlejuice Beetlejuice          7.1  2024
# 397                                The Idea of You          6.4  2024
# 398                                             IF          6.7  2024
# 399                                   The Fall Guy          7.1  2024
#
#     Certificates      Genre               Director  \
# 0              R     Action           Ridley Scott
# ...

# %%
data.head(66)
# Out:
#                                             Title  IMDb Rating  Year  \
# 0                                       Gladiator          8.5  2000
# 1   Mission: Impossible - Dead Reckoning Part One          7.7  2023
# 2            Rebel Moon - Part Two: The Scargiver          5.2  2024
# 3                            Inglourious Basterds          8.4  2009
# 4                                     Borderlands          7.1  2024
# ..                                            ...          ...   ...
# 61                                           Coco          8.4  2017
# 62                                         Frozen          7.4  2013
# 63                          Mufasa: The Lion King          7.1  2024
# 64                           Howl's Moving Castle          8.2  2004
# 65                                       Zootopia          8.0  2016
#
#    Certificates      Genre               Director  \
# 0             R     Action           Ridley Scott
# ...

# %%
data.tail(53)
# Out:
#                                 Title  IMDb Rating  Year Certificates  \
# 347                Mad Max: Fury Road          8.1  2015            R
# 348                             Atlas          5.6  2024        PG-13
# 349           Furiosa: A Mad Max Saga          7.9  2024            R
# 350           Red, White & Royal Blue          7.0  2023            R
# 351                   Despicable Me 4          7.1  2024           PG
# 352                         Migration          6.7  2023           PG
# 353           Ghostbusters: Afterlife          7.0  2021        PG-13
# 354                  Sasquatch Sunset          5.6  2024            R
# 355        10 Things I Hate About You          7.3  1999        PG-13
# 356                             Babes          6.5  2024            R
# 357                  No Hard Feelings          6.4  2023            R
# 358                      Ghostbusters          7.8  1984           PG
# ...

# %%
data.isna().sum()
# Out:
# Title                 0
# IMDb Rating           0
# Year                  0
# Certificates          0
# Genre                 0
# Director              0
# Star Cast             0
# MetaScore             0
# Duration (minutes)    0
# dtype: int64

# %%
highest_rated = data.nlargest(10, 'IMDb Rating')
print(highest_rated)
# Out:
#                                                  Title  IMDb Rating  Year  \
# 137                                      The Godfather          9.2  1972
# 106                                       12 Angry Men          9.0  1957
# 130                                    The Dark Knight          9.0  2008
# 15   The Lord of the Rings: The Fellowship of the Ring          8.9  2001
# 132                                       Pulp Fiction          8.9  1994
# 14                                           Inception          8.8  2010
# 221                                          Inception          8.8  2010
# 24                                        Interstellar          8.7  2014
# 125                                         Goodfellas          8.7  1990
# 211                                         The Matrix          8.7  1999
#
#     Certificates      Genre              Director  \
# 137            R      Crime  Francis Ford Coppola
# 106     Approved      Crime          Sidney Lumet
# ...

# %%
# Analyze the distribution of movie durations
plt.figure(figsize=(10, 6))
sns.histplot(data['Duration (minutes)'], bins=30)
plt.title('Distribution of Movie Durations')
plt.xlabel('Duration (minutes)')
plt.ylabel('Count')
plt.show()

# %%
# Explore the relationship between IMDb Rating and MetaScore
plt.figure(figsize=(10, 6))
sns.scatterplot(x='IMDb Rating', y='MetaScore', data=data)
plt.title('Relationship between IMDb Rating and MetaScore')
plt.xlabel('IMDb Rating')
plt.ylabel('MetaScore')
plt.show()

# %%
# Analyze the popularity of different genres
genre_counts = data['Genre'].value_counts()
plt.figure(figsize=(10, 6))
sns.barplot(x=genre_counts.index, y=genre_counts.values)
plt.title('Popularity of Different Genres')
plt.xlabel('Genre')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# %%
# Distribution of IMDb Ratings
plt.hist(data['IMDb Rating'], bins=20)
plt.title('Distribution of IMDb Ratings')
plt.xlabel('IMDb Rating')
plt.ylabel('Frequency')
plt.show()

# %%
#  Relationship Between IMDb Rating and MetaScore
plt.scatter(data['IMDb Rating'], data['MetaScore'])
plt.title('IMDb Rating vs. MetaScore')
plt.xlabel('IMDb Rating')
plt.ylabel('MetaScore')
plt.show()

# %%
# Most Popular Genres
genre_counts = data['Genre'].value_counts()
plt.bar(genre_counts.index, genre_counts)
plt.title('Most Popular Genres')
plt.xlabel('Genre')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# %%
# Distribution of IMDb Ratings
sns.histplot(data['IMDb Rating'], kde=True)
plt.title('Distribution of IMDb Ratings')
plt.show()

# %%
# Select the columns you want to visualize in the heatmap
columns_to_visualize = ['IMDb Rating', 'Year', 'MetaScore', 'Duration (minutes)']

# Create the correlation matrix
correlation_matrix = data[columns_to_visualize].corr()

# Create the heatmap
sns.heatmap(correlation_matrix, annot=True, cmap='viridis')
plt.title('Correlation Matrix for Movie Attributes')
plt.show()

# %%
sns.catplot(x='Genre', y='IMDb Rating', data=data)
plt.title('IMDb Rating by Genre')
plt.show()

# %%
sns.violinplot(x='Genre', y='IMDb Rating', data=data)
plt.title('IMDb Rating Distribution by Genre')
plt.show()

# %%
genre_counts = data['Genre'].value_counts()
plt.figure(figsize=(10, 7))
plt.pie(genre_counts, labels=genre_counts.index, autopct='%1.1f%%', colors=plt.cm.tab20.colors, startangle=140)
plt.title('Distribution of Genres')
plt.show()

# %%
data = pd.read_csv(r"C:\Users\revan\Downloads\IMDb_Dataset_2.csv")

# %%
data
# Out:
#                                               Title  IMDb Rating  Year  \
# 0                                  End of the Spear          6.8  2005
# 1                                    Elvira Madigan          7.0  1967
# 2                      The Kid Stays in the Picture          7.3  2002
# 3                                     It Ain't Over          8.2  2022
# 4                                            Mahler          7.0  1974
# ...                                             ...          ...   ...
# 3168  The Lord of the Rings: The Return of the King          9.0  2003
# 3169                               Schindler's List          9.0  1993
# 3170                                The Dark Knight          9.0  2008
# 3171                                  The Godfather          9.2  1972
# 3172                       The Shawshank Redemption          9.3  1994
#
#      Certificates        Genre              Director  \
# 0           PG-13    Adventure             Jim Hanon
# ...

# %%
data.head(40)
# Out:
#                                         Title  IMDb Rating  Year Certificates  \
# 0                            End of the Spear          6.8  2005        PG-13
# 1                              Elvira Madigan          7.0  1967           PG
# 2                The Kid Stays in the Picture          7.3  2002            R
# 3                               It Ain't Over          8.2  2022           PG
# 4                                      Mahler          7.0  1974           PG
# 5                              The Dark Horse          7.4  2014            R
# 6                   Stephen Curry: Underrated          7.3  2023        PG-13
# 7                                  Carrington          6.8  1995            R
# 8                                      Burden          6.7  2018            R
# 9                                  Georgetown          6.2  2019            R
# 10                                Miles Ahead          6.4  2015            R
# ...

# %%
data.tail(55)
# Out:
#                                                   Title  IMDb Rating  Year  \
# 3118                                       Modern Times          8.5  1936
# 3119                                    Cinema Paradiso          8.5  1988
# 3120                             Grave of the Fireflies          8.5  1988
# 3121                                   The Intouchables          8.5  2011
# 3122                                         Casablanca          8.5  1942
# 3123                                        Rear Window          8.5  1954
# 3124                                        The Pianist          8.5  2002
# 3125                       Once Upon a Time in the West          8.5  1968
# 3126                                 American History X          8.5  1998
# 3127                                             Psycho          8.5  1960
# 3128                                      The Lion King          8.5  1994
# ...

# %%
# Check for missing values
print(data.isnull().sum())
# Out:
# Title                 0
# IMDb Rating           0
# Year                  0
# Certificates          0
# Genre                 0
# Director              0
# Star Cast             0
# MetaScore             0
# Duration (minutes)    0
# dtype: int64

# %%
# Calculate descriptive statistics for numerical columns (IMDb Rating, Year, MetaScore, Duration)
numerical_columns = ['IMDb Rating', 'Year', 'MetaScore', 'Duration (minutes)']
print(data[numerical_columns].describe())
# Out:
#        IMDb Rating         Year   MetaScore  Duration (minutes)
# count   400.000000   400.000000  400.000000          400.000000
# mean      7.110250  2015.150000   66.898750          116.334750
# std       0.932251    13.470194   15.312006           21.369757
# min       3.900000  1939.000000   26.000000           80.000000
# 25%       6.700000  2010.750000   57.750000          101.000000
# 50%       7.100000  2023.000000   66.900000          116.000000
# 75%       7.700000  2024.000000   77.000000          124.000000
# max       9.200000  2025.000000  100.000000          206.000000

# %%
# Explore highest rated movies by genre
highest_rated_by_genre = data.groupby('Genre')['IMDb Rating'].max().reset_index()
print(highest_rated_by_genre.sort_values(by='IMDb Rating', ascending=False))
# Out:
#        Genre  IMDb Rating
# 5      Crime          9.2
# 0     Action          9.0
# 1  Adventure          8.7
# 3  Biography          8.7
# 2  Animation          8.6
# 4     Comedy          8.5
# 8     Horror          8.5
# 6      Drama          8.0
# 9   Thriller          7.4
# 7    Fantasy          7.3

# %%
# Find movies with duration exceeding a specific threshold (e.g., 200 minutes)
long_movies = data[data['Duration (minutes)'] > 200]
print(long_movies)
# Out:
#                           Title  IMDb Rating  Year Certificates   Genre  \
# 104                      Animal          6.2  2023    Not Rated  Action
# 131  Killers of the Flower Moon          7.6  2023            R   Crime
#
#                 Director                                      Star Cast  \
# 104  Sandeep Reddy Vanga  Suresh BandaruSaurabh GuptaPranay Reddy Vanga
# 131      Martin Scorsese  Leonardo DiCaprioRobert De NiroLily Gladstone
#
#      MetaScore  Duration (minutes)
# 104       33.0               204.0
# 131       89.0               206.0

# %%
# Exploring average rating by Genre
sns.catplot(x='Genre', y='IMDb Rating', data=data)
plt.title('Average IMDb Rating by Genre Distribution')
plt.show()

# %%
# Exploring distribution of rating within Genre using Violinplot
sns.violinplot(x='Genre', y='IMDb Rating', data=data)
plt.title('IMDb Rating Distribution by Genre')
plt.show()

# %%
# Exploring Correlation between numeric variables
numeric_cols = ['IMDb Rating', 'Year', 'MetaScore', 'Duration (minutes)']
correlation = data[numeric_cols].corr()
# Create a heatmap
sns.heatmap(correlation, annot=True, cmap='viridis')
plt.title('Correlation Matrix for Movie Attributes')
plt.show()

# %%
data = pd.read_csv(r"C:\Users\revan\Downloads\IMDb_Dataset_3.csv")

# %%
data
# Out:
#                              Title         Director         Star Cast  Year  \
# 0          The Biggest Little Farm     John Chester      John Chester  2018
# 1           Pokémon the Movie 2000  Kunihiko Yuyama   Veronica Taylor  1999
# 2    When Hitler Stole Pink Rabbit    Caroline Link  Riva Krymalowski  2019
# 3       Return from Witch Mountain       John Hough       Bette Davis  1978
# 4                     Summer Magic    James Neilson      Hayley Mills  1963
# ..                             ...              ...               ...   ...
# 995          The Boy and the Heron   Hayao Miyazaki      Soma Santoki  2023
# 996                Despicable Me 4     Chris Renaud      Steve Carell  2024
# 997                     Inside Out      Pete Docter       Amy Poehler  2015
# 998                             IF   John Krasinski    Cailey Fleming  2024
# 999                   Inside Out 2      Kelsey Mann       Amy Poehler  2024
#
# ...

# %%
data.head(78)
# Out:
#                                    Title          Director         Star Cast  \
# 0                The Biggest Little Farm      John Chester      John Chester
# 1                 Pokémon the Movie 2000   Kunihiko Yuyama   Veronica Taylor
# 2          When Hitler Stole Pink Rabbit     Caroline Link  Riva Krymalowski
# 3             Return from Witch Mountain        John Hough       Bette Davis
# 4                           Summer Magic     James Neilson      Hayley Mills
# ..                                   ...               ...               ...
# 73                        Spirit Untamed      Elaine Bogan    Isabela Merced
# 74            Godzilla vs. Mechagodzilla        Jun Fukuda    Masaaki Daimon
# 75                        Hotel for Dogs  Thor Freudenthal      Emma Roberts
# 76  The Adventures of Rocky & Bullwinkle       Des McAnuff    Robert De Niro
# 77                   Friendly Persuasion     William Wyler       Gary Cooper
#
# ...

# %%
data.tail(56)
# Out:
#                                             Title            Director  \
# 944             Charlie and the Chocolate Factory          Tim Burton
# 945                                        Frozen          Chris Buck
# 946                              The Wizard of Oz      Victor Fleming
# 947                                  Finding Nemo      Andrew Stanton
# 948                          Howl's Moving Castle      Hayao Miyazaki
# 949                                Monsters, Inc.         Pete Docter
# 950                                     Labyrinth          Jim Henson
# 951           Willy Wonka & the Chocolate Factory          Mel Stuart
# 952      Harry Potter and the Prisoner of Azkaban      Alfonso Cuarón
# 953                           Night at the Museum          Shawn Levy
# 954                                      Zootopia        Byron Howard
# 955                                   Unsung Hero   Richard L. Ramsey
# ...

# %%
data.isna().sum()
# Out:
# Title                 0
# Director              0
# Star Cast             0
# Year                  0
# IMDb Rating           0
# MetaScore             0
# Certificates          0
# Genre                 0
# Second_Genre          0
# Third_Genre           0
# Poster-src            0
# Duration (minutes)    0
# dtype: int64

# %%
# Check for missing values
print(data.isnull().sum())
# Out:
# Title                 0
# Director              0
# Star Cast             0
# Year                  0
# IMDb Rating           0
# MetaScore             0
# Certificates          0
# Genre                 0
# Second_Genre          0
# Third_Genre           0
# Poster-src            0
# Duration (minutes)    0
# dtype: int64

# %%
# Basic info about the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3173 entries, 0 to 3172
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Title               3173 non-null   object
#  1   IMDb Rating         3173 non-null   float64
#  2   Year                3173 non-null   int64
#  3   Certificates        3173 non-null   object
#  4   Genre               3173 non-null   object
#  5   Director            3173 non-null   object
#  6   Star Cast           3173 non-null   object
#  7   MetaScore           3173 non-null   float64
#  8   Poster-src          3173 non-null   object
#  9   Duration (minutes)  3173 non-null   float64
# dtypes: float64(3), int64(1), object(6)
# memory usage: 248.0+ KB

# %%
# Summary statistics of numerical columns
df.describe()
# Out:
#        IMDb Rating         Year    MetaScore  Duration (minutes)
# count  3173.000000  3173.000000  3173.000000         3173.000000
# mean      6.931012  2004.958399    65.993066          116.304822
# std       0.805202    16.819985    11.358619           22.123032
# min       3.900000  1917.000000    20.000000           46.000000
# 25%       6.400000  1997.000000    64.000000          105.000000
# 50%       6.900000  2010.000000    66.000000          116.300000
# 75%       7.500000  2017.000000    69.000000          122.000000
# max       9.500000  2025.000000   100.000000          317.000000

# %%
# Plot IMDb rating distribution
sns.histplot(data['IMDb Rating'], bins=10, kde=True)
plt.title('Distribution of IMDb Ratings')
plt.show()

# %%
# Calculate descriptive statistics for numerical columns (IMDb Rating, Year, MetaScore, Duration)
numerical_columns = ['IMDb Rating', 'Year', 'MetaScore', 'Duration (minutes)']
print(data[numerical_columns].describe())
# Out:
#        IMDb Rating         Year    MetaScore  Duration (minutes)
# count  1000.000000  1000.000000  1000.000000         1000.000000
# mean      6.418700  2003.178000    57.077100          100.034000
# std       0.943064    18.697216    15.051861           17.032938
# min       4.000000  1921.000000    11.000000           55.000000
# 25%       5.800000  1995.000000    48.000000           90.000000
# 50%       6.400000  2007.500000    57.100000           98.000000
# 75%       7.100000  2017.000000    66.000000          106.000000
# max       8.600000  2024.000000    99.000000          260.000000

# %%
print(data.isnull().sum())  # Check for missing values
data['MetaScore'] = pd.to_numeric(data['MetaScore'], errors='coerce')  # Convert MetaScore to numeric
# Out:
# Title                 0
# Director              0
# Star Cast             0
# Year                  0
# IMDb Rating           0
# MetaScore             0
# Certificates          0
# Genre                 0
# Second_Genre          0
# Third_Genre           0
# Poster-src            0
# Duration (minutes)    0
# dtype: int64

# %%
mean_rating = np.mean(data['IMDb Rating'])
median_rating = np.median(data['IMDb Rating'])
std_rating = np.std(data['IMDb Rating'])

print(f'Mean IMDb Rating: {mean_rating}')
print(f'Median IMDb Rating: {median_rating}')
print(f'Standard Deviation of IMDb Rating: {std_rating}')
# Out:
# Mean IMDb Rating: 6.418699999999999
# Median IMDb Rating: 6.4
# Standard Deviation of IMDb Rating: 0.9425923349996006

# %%
genre_ratings = data.groupby('Genre')['IMDb Rating'].mean()
print(genre_ratings)

year_ratings = data.groupby('Year')['IMDb Rating'].mean()
print(year_ratings)
# Out:
# Genre
# Action         5.704348
# Adventure      6.233178
# Animation      6.747089
# Biography      7.181818
# Comedy         6.020305
# Crime          6.550000
# Documentary    8.000000
# Drama          7.040625
# Family         6.092308
# Name: IMDb Rating, dtype: float64
# Year
# 1921    8.200000
# 1930    7.400000
# 1937    7.366667
# 1939    8.100000
# 1940    7.320000
#           ...
# 2020    6.200000
# 2021    6.202941
# 2022    6.004444
# 2023    6.310638
# 2024    6.253333
# Name: IMDb Rating, Length: 88, dtype: float64

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
genre_ratings.plot(kind='bar')
plt.title('Average IMDb Rating by Genre')
plt.xlabel('Genre')
plt.ylabel('Average IMDb Rating')
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.hist(data['IMDb Rating'], bins=10, color='green', alpha=0.7)
plt.title('Distribution of IMDb Ratings')
plt.xlabel('IMDb Rating')
plt.ylabel('Frequency')
plt.grid(axis='y')
plt.show()

# %%
avg_rating_by_genre = data.groupby('Genre')['IMDb Rating'].mean().sort_values()
plt.figure(figsize=(12, 6))
avg_rating_by_genre.plot(kind='barh', color='orange')
plt.title('Average IMDb Rating by Genre')
plt.xlabel('Average IMDb Rating')
plt.ylabel('Genre')
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.scatter(data['MetaScore'], data['IMDb Rating'], alpha=0.5)
plt.title('IMDb Rating vs. MetaScore')
plt.xlabel('MetaScore')
plt.ylabel('IMDb Rating')
plt.grid()
plt.show()

# %%
# Create a violin plot
plt.figure(figsize=(12, 6))
sns.violinplot(x='Genre', y='IMDb Rating', data=data)
plt.xticks(rotation=45)
plt.title('Distribution of IMDb Ratings by Genre')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='Genre', y='IMDb Rating', data=data)
plt.title('Boxplot of IMDb Ratings by Certificate')
plt.show()

# %%
# Average IMDb Rating and MetaScore by Genre
avg_rating_by_genre = data.groupby('Genre')['IMDb Rating'].mean()
avg_metascore_by_genre = data.groupby('Genre')['MetaScore'].mean()

print(avg_rating_by_genre)
print(avg_metascore_by_genre)
# Out:
# Genre
# Action         5.704348
# Adventure      6.233178
# Animation      6.747089
# Biography      7.181818
# Comedy         6.020305
# Crime          6.550000
# Documentary    8.000000
# Drama          7.040625
# Family         6.092308
# Name: IMDb Rating, dtype: float64
# Genre
# Action         49.677174
# Adventure      54.476168
# Animation      62.573418
# Biography      55.468182
# Comedy         51.114213
# Crime          60.000000
# Documentary    73.000000
# Drama          61.384375
# Family         55.461538
# Name: MetaScore, dtype: float64

# %%
# Visualizing Average IMDb Rating by Genre
plt.figure(figsize=(10,6))
sns.barplot(x=avg_rating_by_genre.index, y=avg_rating_by_genre.values)
plt.title('Average IMDb Rating by Genre')
plt.xlabel('Genre')
plt.ylabel('Average IMDb Rating')
plt.xticks(rotation=90)
plt.show()

# %%
# Visualizing Average MetaScore by Genre
plt.figure(figsize=(10,6))
sns.barplot(x=avg_metascore_by_genre.index, y=avg_metascore_by_genre.values)
plt.title('Average MetaScore by Genre')
plt.xlabel('Genre')
plt.ylabel('Average MetaScore')
plt.xticks(rotation=90)
plt.show()

# %%
# Distribution of IMDb Ratings
plt.figure(figsize=(8,6))
sns.histplot(data['IMDb Rating'], bins=10)
plt.title('Distribution of IMDb Ratings')
plt.xlabel('IMDb Rating')
plt.ylabel('Frequency')
plt.show()

# %%
# Scatter plot of IMDb Rating vs MetaScore
plt.figure(figsize=(10,6))
sns.scatterplot(data=data, x='MetaScore', y='IMDb Rating', hue='Genre')
plt.title('IMDb Rating vs MetaScore')
plt.show()

# %%
# Distribution of Movie Durations
plt.figure(figsize=(8,6))
sns.histplot(data['Duration (minutes)'], bins=10)
plt.title('Distribution of Movie Durations')
plt.xlabel('Duration (minutes)')
plt.ylabel('Frequency')
plt.show()

# %%
# Average movie duration by Genre
avg_duration_by_genre = data.groupby('Genre')['Duration (minutes)'].mean()
print(avg_duration_by_genre)
# Out:
# Genre
# Action       124.318841
# Adventure    124.645714
# Animation    102.667368
# Biography    150.500000
# Comedy       112.973684
# Crime        126.203226
# Drama        115.837500
# Fantasy      109.460000
# Horror       103.824138
# Thriller     116.300000
# Name: Duration (minutes), dtype: float64

# %%
# Visualizing Average Duration by Genre
plt.figure(figsize=(10,6))
sns.barplot(x=avg_duration_by_genre.index, y=avg_duration_by_genre.values)
plt.title('Average Movie Duration by Genre')
plt.xlabel('Genre')
plt.ylabel('Average Duration (minutes)')
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(10, 6))
data['Certificates'].value_counts().plot(kind='bar', color='cyan', edgecolor='black')
plt.title('Count of Movies by Certificates')
plt.xlabel('Certificates')
plt.ylabel('Number of Movies')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.histplot(data['IMDb Rating'], bins=15, kde=True, color='blue')
plt.title('Distribution of IMDb Ratings')
plt.xlabel('IMDb Rating')
plt.ylabel('Frequency')
plt.show()
