# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# dataset load
data = pd.read_csv(r"C:\Users\revan\Downloads\customer_purchase_data.csv")

# %%
data
# Out:
#       Age  Gender   AnnualIncome  NumberOfPurchases  ProductCategory  \
# 0      40       1   66120.267939                  8                0
# 1      20       1   23579.773583                  4                2
# 2      27       1  127821.306432                 11                2
# 3      24       1  137798.623120                 19                3
# 4      31       1   99300.964220                 19                1
# ...   ...     ...            ...                ...              ...
# 1495   39       1   65048.141834                 13                0
# 1496   67       1   28775.331069                 18                2
# 1497   40       1   57363.247541                  7                4
# 1498   63       0  134021.775532                 16                2
# 1499   50       0   52625.665974                 13                0
#
#       TimeSpentOnWebsite  LoyaltyProgram  DiscountsAvailed  PurchaseStatus
# ...

# %%
data.head(29)
# Out:
#     Age  Gender   AnnualIncome  NumberOfPurchases  ProductCategory  \
# 0    40       1   66120.267939                  8                0
# 1    20       1   23579.773583                  4                2
# 2    27       1  127821.306432                 11                2
# 3    24       1  137798.623120                 19                3
# 4    31       1   99300.964220                 19                1
# 5    66       1   37758.117475                 14                4
# 6    39       1  126883.385286                 16                3
# 7    64       1   39707.359724                 13                2
# 8    43       0  102797.301269                 20                1
# 9    20       1   63854.921080                 16                0
# 10   66       1   66199.993929                 11                1
# 11   70       1   83556.718133                 11                2
# 12   54       0  114467.228969                  9                2
# ...

# %%
data.tail(24)
# Out:
#       Age  Gender   AnnualIncome  NumberOfPurchases  ProductCategory  \
# 1476   22       1  113951.904501                  2                0
# 1477   29       0  112824.243781                 20                4
# 1478   35       1   97367.117738                 14                2
# 1479   24       0  125414.215531                 11                4
# 1480   39       0   34204.347340                 17                3
# 1481   49       0   95780.387385                 18                0
# 1482   32       1   35979.688201                 11                1
# 1483   55       0   81936.808225                  6                1
# 1484   68       0   80311.223269                 14                2
# 1485   21       1  120794.999552                 10                0
# 1486   28       1  141304.733075                  0                1
# 1487   41       0  116615.115835                 19                2
# 1488   22       0   55799.552653                  9                4
# ...

# %%
data.describe()
# Out:
#                Age       Gender   AnnualIncome  NumberOfPurchases  \
# count  1500.000000  1500.000000    1500.000000        1500.000000
# mean     44.298667     0.504667   84249.164338          10.420000
# std      15.537259     0.500145   37629.493078           5.887391
# min      18.000000     0.000000   20001.512518           0.000000
# 25%      31.000000     0.000000   53028.979155           5.000000
# 50%      45.000000     1.000000   83699.581476          11.000000
# 75%      57.000000     1.000000  117167.772858          15.000000
# max      70.000000     1.000000  149785.176481          20.000000
#
#        ProductCategory  TimeSpentOnWebsite  LoyaltyProgram  DiscountsAvailed  \
# count      1500.000000         1500.000000     1500.000000       1500.000000
# mean          2.012667           30.469040        0.326667          2.555333
# std           1.428005           16.984392        0.469151          1.705152
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1500 entries, 0 to 1499
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Age                 1500 non-null   int64
#  1   Gender              1500 non-null   int64
#  2   AnnualIncome        1500 non-null   float64
#  3   NumberOfPurchases   1500 non-null   int64
#  4   ProductCategory     1500 non-null   int64
#  5   TimeSpentOnWebsite  1500 non-null   float64
#  6   LoyaltyProgram      1500 non-null   int64
#  7   DiscountsAvailed    1500 non-null   int64
#  8   PurchaseStatus      1500 non-null   int64
# dtypes: float64(2), int64(7)
# memory usage: 105.6 KB

# %%
data.columns
# Out:
# Index(['Age', 'Gender', 'AnnualIncome', 'NumberOfPurchases', 'ProductCategory',
#        'TimeSpentOnWebsite', 'LoyaltyProgram', 'DiscountsAvailed',
#        'PurchaseStatus'],
#       dtype='object')

# %%
list(data.columns)
# Out:
# ['Age',
#  'Gender',
#  'AnnualIncome',
#  'NumberOfPurchases',
#  'ProductCategory',
#  'TimeSpentOnWebsite',
#  'LoyaltyProgram',
#  'DiscountsAvailed',
#  'PurchaseStatus']

# %%
data.isnull().head(25)
# Out:
#       Age  Gender  AnnualIncome  NumberOfPurchases  ProductCategory  \
# 0   False   False         False              False            False
# 1   False   False         False              False            False
# 2   False   False         False              False            False
# 3   False   False         False              False            False
# 4   False   False         False              False            False
# 5   False   False         False              False            False
# 6   False   False         False              False            False
# 7   False   False         False              False            False
# 8   False   False         False              False            False
# 9   False   False         False              False            False
# 10  False   False         False              False            False
# 11  False   False         False              False            False
# 12  False   False         False              False            False
# ...

# %%
data.isnull().sum()
# Out:
# Age                   0
# Gender                0
# AnnualIncome          0
# NumberOfPurchases     0
# ProductCategory       0
# TimeSpentOnWebsite    0
# LoyaltyProgram        0
# DiscountsAvailed      0
# PurchaseStatus        0
# dtype: int64

# %%
data.isna().any()
# Out:
# Age                   False
# Gender                False
# AnnualIncome          False
# NumberOfPurchases     False
# ProductCategory       False
# TimeSpentOnWebsite    False
# LoyaltyProgram        False
# DiscountsAvailed      False
# PurchaseStatus        False
# dtype: bool

# %%
data['Gender'].head()
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# Name: Gender, dtype: int64

# %%
data[['Gender','AnnualIncome']].head()
# Out:
#    Gender   AnnualIncome
# 0       1   66120.267939
# 1       1   23579.773583
# 2       1  127821.306432
# 3       1  137798.623120
# 4       1   99300.964220

# %%
data[data.index==6]
# Out:
#    Age  Gender   AnnualIncome  NumberOfPurchases  ProductCategory  \
# 6   39       1  126883.385286                 16                3
#
#    TimeSpentOnWebsite  LoyaltyProgram  DiscountsAvailed  PurchaseStatus
# 6           42.085384               1                 4               1

# %%
data[data.index.isin(range(2,10))]
# Out:
#    Age  Gender   AnnualIncome  NumberOfPurchases  ProductCategory  \
# 2   27       1  127821.306432                 11                2
# 3   24       1  137798.623120                 19                3
# 4   31       1   99300.964220                 19                1
# 5   66       1   37758.117475                 14                4
# 6   39       1  126883.385286                 16                3
# 7   64       1   39707.359724                 13                2
# 8   43       0  102797.301269                 20                1
# 9   20       1   63854.921080                 16                0
#
#    TimeSpentOnWebsite  LoyaltyProgram  DiscountsAvailed  PurchaseStatus
# 2           31.633212               1                 0               1
# 3           46.167059               0                 4               1
# 4           19.823592               0                 0               1
# 5           17.827493               0                 2               0
# ...

# %%
data[['AnnualIncome','ProductCategory']].head()
# Out:
#     AnnualIncome  ProductCategory
# 0   66120.267939                0
# 1   23579.773583                2
# 2  127821.306432                2
# 3  137798.623120                3
# 4   99300.964220                1

# %%
data[data.index==4]
# Out:
#    Age  Gender  AnnualIncome  NumberOfPurchases  ProductCategory  \
# 4   31       1   99300.96422                 19                1
#
#    TimeSpentOnWebsite  LoyaltyProgram  DiscountsAvailed  PurchaseStatus
# 4           19.823592               0                 0               1

# %%
data[data.index.isin(range(2,10))]
# Out:
#    Age  Gender   AnnualIncome  NumberOfPurchases  ProductCategory  \
# 2   27       1  127821.306432                 11                2
# 3   24       1  137798.623120                 19                3
# 4   31       1   99300.964220                 19                1
# 5   66       1   37758.117475                 14                4
# 6   39       1  126883.385286                 16                3
# 7   64       1   39707.359724                 13                2
# 8   43       0  102797.301269                 20                1
# 9   20       1   63854.921080                 16                0
#
#    TimeSpentOnWebsite  LoyaltyProgram  DiscountsAvailed  PurchaseStatus
# 2           31.633212               1                 0               1
# 3           46.167059               0                 4               1
# 4           19.823592               0                 0               1
# 5           17.827493               0                 2               0
# ...

# %%
data.loc[5]
# Out:
# Age                      66.000000
# Gender                    1.000000
# AnnualIncome          37758.117475
# NumberOfPurchases        14.000000
# ProductCategory           4.000000
# TimeSpentOnWebsite       17.827493
# LoyaltyProgram            0.000000
# DiscountsAvailed          2.000000
# PurchaseStatus            0.000000
# Name: 5, dtype: float64

# %%
data.iloc[4]
# Out:
# Age                      31.000000
# Gender                    1.000000
# AnnualIncome          99300.964220
# NumberOfPurchases        19.000000
# ProductCategory           1.000000
# TimeSpentOnWebsite       19.823592
# LoyaltyProgram            0.000000
# DiscountsAvailed          0.000000
# PurchaseStatus            1.000000
# Name: 4, dtype: float64

# %%
data.iloc[2:10]
# Out:
#    Age  Gender   AnnualIncome  NumberOfPurchases  ProductCategory  \
# 2   27       1  127821.306432                 11                2
# 3   24       1  137798.623120                 19                3
# 4   31       1   99300.964220                 19                1
# 5   66       1   37758.117475                 14                4
# 6   39       1  126883.385286                 16                3
# 7   64       1   39707.359724                 13                2
# 8   43       0  102797.301269                 20                1
# 9   20       1   63854.921080                 16                0
#
#    TimeSpentOnWebsite  LoyaltyProgram  DiscountsAvailed  PurchaseStatus
# 2           31.633212               1                 0               1
# 3           46.167059               0                 4               1
# 4           19.823592               0                 0               1
# 5           17.827493               0                 2               0
# ...

# %%
print("Basic Statistics:")
print(data.describe())
# Out:
# Basic Statistics:
#                Age       Gender   AnnualIncome  NumberOfPurchases  \
# count  1500.000000  1500.000000    1500.000000        1500.000000
# mean     44.298667     0.504667   84249.164338          10.420000
# std      15.537259     0.500145   37629.493078           5.887391
# min      18.000000     0.000000   20001.512518           0.000000
# 25%      31.000000     0.000000   53028.979155           5.000000
# 50%      45.000000     1.000000   83699.581476          11.000000
# 75%      57.000000     1.000000  117167.772858          15.000000
# max      70.000000     1.000000  149785.176481          20.000000
#
#        ProductCategory  TimeSpentOnWebsite  LoyaltyProgram  DiscountsAvailed  \
# count      1500.000000         1500.000000     1500.000000       1500.000000
# mean          2.012667           30.469040        0.326667          2.555333
# std           1.428005           16.984392        0.469151          1.705152
# ...

# %%
plt.figure(figsize=(10, 6))
sns.heatmap(data.corr(), annot=True, cmap='coolwarm')
plt.title("Correlation Heatmap")
plt.show()

# %%
plt.figure(figsize=(5, 3))
sns.boxplot(x='Gender', y='AnnualIncome', data=data)
plt.title("Annual Income Distribution by Gender")
plt.show()

# %%
plt.figure(figsize=(11, 5))
sns.countplot(x='PurchaseStatus', data=data)
plt.title("Purchase Status Distribution")
plt.show()

# %%
plt.figure(figsize=(10,8))
sns.boxplot(x='PurchaseStatus', y='TimeSpentOnWebsite', data=data)
plt.title("Time Spent on Website vs. Purchase Status")
plt.show()

# %%
plt.figure(figsize=(10, 3))
sns.countplot(x='LoyaltyProgram', hue='PurchaseStatus', data=data)
plt.title("Loyalty Program vs Purchase Status")
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.boxplot(x='PurchaseStatus', y='DiscountsAvailed', data=data)
plt.title("Discounts Availed vs Purchase Status")
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.histplot(data,x='Age',bins=30,kde=True)
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
correlation_income_purchases = data[['AnnualIncome', 'NumberOfPurchases']].corr().iloc[0, 1]
print(f"\nCorrelation between Annual Income and Number of Purchases: {correlation_income_purchases:.2f}")
# Out:
# Correlation between Annual Income and Number of Purchases: 0.00

# %%
# Group by Purchase Status and calculate mean values
grouped = data.groupby('PurchaseStatus').mean()
print("\nMean Values by Purchase Status:")
print(grouped)
# Out:
# Mean Values by Purchase Status:
#                       Age    Gender  AnnualIncome  NumberOfPurchases  \
# PurchaseStatus
# 0               47.762911  0.503521  78074.638282           9.276995
# 1               39.743827  0.506173  92367.522671          11.922840
#
#                 ProductCategory  TimeSpentOnWebsite  LoyaltyProgram  \
# PurchaseStatus
# 0                      2.003521           26.365784        0.199531
# 1                      2.024691           35.864062        0.493827
#
#                 DiscountsAvailed
# PurchaseStatus
# 0                       2.104460
# 1                       3.148148

# %%
# Additional Analysis: Count of PurchaseStatus
status_counts = data['PurchaseStatus'].value_counts()
print("\nCount of Purchase Status:")
print(status_counts)
# Out:
# Count of Purchase Status:
# PurchaseStatus
# 0    852
# 1    648
# Name: count, dtype: int64

# %%
plt.subplot(3, 2, 2)
plt.hist(data['AnnualIncome'], bins=10, color='salmon', edgecolor='black')
plt.title('Annual Income Distribution')
plt.xlabel('Annual Income')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
avg_purchases_by_status = data.groupby('PurchaseStatus')['NumberOfPurchases'].mean()
plt.figure(figsize=(8, 6))
avg_purchases_by_status.plot(kind='bar', color='teal')
plt.title('Average Number of Purchases by Purchase Status')
plt.xlabel('Purchase Status')
plt.ylabel('Average Number of Purchases')
plt.xticks(rotation=0)
plt.show()

# %%
# Plot distributions using seaborn
plt.figure(figsize=(14, 10))

plt.subplot(2, 2, 1)
sns.histplot(data['Age'], bins=10, kde=True, color='skyblue')
plt.title('Age Distribution')
# Out:
# Text(0.5, 1.0, 'Age Distribution')

# %%
plt.subplot(2, 2, 2)
sns.histplot(data['AnnualIncome'], bins=10, kde=True, color='salmon')
plt.title('Annual Income Distribution')
# Out:
# Text(0.5, 1.0, 'Annual Income Distribution')

# %%
# Scatter plot for Annual Income vs Number of Purchases
plt.figure(figsize=(8, 6))
sns.scatterplot(x='AnnualIncome', y='NumberOfPurchases', data=data, hue='PurchaseStatus', palette='deep')
plt.title('Annual Income vs Number of Purchases')
plt.xlabel('Annual Income')
plt.ylabel('Number of Purchases')
plt.legend(title='Purchase Status')
plt.grid(True)
plt.show()

# %%
# Pair plot to see relationships between numerical features
sns.pairplot(data, hue='PurchaseStatus', palette='husl')
plt.show()

# %%
correlation_matrix = data.corr()
# Create a heatmap to visualize the correlation matrix
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f', vmin=-1, vmax=1)
plt.title('Correlation Heatmap')
plt.show()

# %%
# Count the occurrences of each purchase status
purchase_status_counts = data['PurchaseStatus'].value_counts()

# Create the pie chart
plt.pie(purchase_status_counts, labels=purchase_status_counts.index, autopct='%1.1f%%')

# Set the title
plt.title('Distribution of Purchase Statuses')

# Display the chart
plt.show()
